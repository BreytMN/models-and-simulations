# %%
# Data Manipulation
import numpy as np
import pandas as pd

pd.set_option('display.max_colwidth', None)

# Data Viz
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# ML Models and Utils
from lightgbm import LGBMClassifier
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier

# Setup
import os
import sys
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Custom Functions
sys.path.insert(0, os.path.abspath("../../../common"))
from utils.data_tools import summary
from utils.model_tools import encoding_labels, train_calib_test_split
from utils.model_tools import report, calibration_report
from utils.plot import plot_countplot, plot_intersections

# %% [markdown]
# # EDA & Preprocessing

# %% [markdown]
# Data taken from [Maven Churn Challenge](https://www.mavenanalytics.io/blog/maven-churn-challenge)

# %%
data_path = '../../../data/telecom_churn'

df = pd.read_csv(f'{data_path}/telecom_customer_churn.csv')
data_population = pd.read_csv(f'{data_path}/telecom_zipcode_population.csv')
data_dict = pd.read_csv(f'{data_path}/telecom_data_dictionary.csv', encoding='ISO-8859-1')

data_dict
# Out:
#                   Table                              Field  \
# 0        Customer Churn                         CustomerID
# 1        Customer Churn                             Gender
# 2        Customer Churn                                Age
# 3        Customer Churn                            Married
# 4        Customer Churn               Number of Dependents
# 5        Customer Churn                               City
# 6        Customer Churn                           Zip Code
# 7        Customer Churn                           Latitude
# 8        Customer Churn                          Longitude
# 9        Customer Churn                Number of Referrals
# 10       Customer Churn                   Tenure in Months
# 11       Customer Churn                              Offer
# 12       Customer Churn                      Phone Service
# 13       Customer Churn  Avg Monthly Long Distance Charges
# 14       Customer Churn                     Multiple Lines
# 15       Customer Churn                   Internet Service
# 16       Customer Churn                      Internet Type
# 17       Customer Churn            Avg Monthly GB Download
# 18       Customer Churn                    Online Security
# 19       Customer Churn                      Online Backup
# 20       Customer Churn             Device Protection Plan
# 21       Customer Churn               Premium Tech Support
# 22       Customer Churn                       Streaming TV
# 23       Customer Churn                   Streaming Movies
# 24       Customer Churn                    Streaming Music
# 25       Customer Churn                     Unlimited Data
# 26       Customer Churn                           Contract
# 27       Customer Churn                  Paperless Billing
# 28       Customer Churn                     Payment Method
# 29       Customer Churn                     Monthly Charge
# 30       Customer Churn                      Total Charges
# 31       Customer Churn                      Total Refunds
# 32       Customer Churn           Total Extra Data Charges
# 33       Customer Churn        Total Long Distance Charges
# 34       Customer Churn                      Total Revenue
# 35       Customer Churn                    Customer Status
# 36       Customer Churn                     Churn Category
# 37       Customer Churn                       Churn Reason
# 38  Zip Code Population                           Zip Code
# 39  Zip Code Population                         Population
#
#                                                                                                                                                                                                                  Description
# 0                                                                                                                                                                                  A unique ID that identifies each customer
# 1                                                                                                                                                                                        The customers gender: Male, Female
# 2                                                                                                                                       The customers current age, in years, at the time the fiscal quarter ended (Q2 2022)
# 3                                                                                                                                                                              Indicates if the customer is married: Yes, No
# 4                                                                                                 Indicates the number of dependents that live with the customer (dependents could be children, parents, grandparents, etc.)
# 5                                                                                                                                                                 The city of the customers primary residence in California
# 6                                                                                                                                                                           The zip code of the customers primary residence
# 7                                                                                                                                                                           The latitude of the customers primary residence
# 8                                                                                                                                                                          The longitude of the customers primary residence
# 9                                                                                                                  Indicates the number of times the customer has referred a friend or family member to this company to date
# 10                                                                                                Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above
# 11                                                                                                         Identifies the last marketing offer that the customer accepted: None, Offer A, Offer B, Offer C, Offer D, Offer E
# 12                                                                                                                                      Indicates if the customer subscribes to home phone service with the company: Yes, No
# 13                                    Indicates the customers average long distance charges, calculated to the end of the quarter specified above (if the customer is not subscribed to home phone service, this will be 0)
# 14                                                     Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No (if the customer is not subscribed to home phone service, this will be No)
# 15                                                                                                                                        Indicates if the customer subscribes to Internet service with the company: Yes, No
# 16                                                                  Indicates the customer's type of internet connection: DSL, Fiber Optic, Cable (if the customer is not subscribed to internet service, this will be None)
# 17                               Indicates the customers average download volume in gigabytes, calculated to the end of the quarter specified above (if the customer is not subscribed to internet service, this will be 0)
# 18                                   Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 19                                     Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 20       Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 21                   Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 22  Indicates if the customer uses their Internet service to stream television programing from a third party provider at no additional fee: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 23                 Indicates if the customer uses their Internet service to stream movies from a third party provider at no additional fee: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 24                  Indicates if the customer uses their Internet service to stream music from a third party provider at no additional fee: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 25                                   Indicates if the customer has paid an additional monthly fee to have unlimited data downloads/uploads: Yes, No (if the customer is not subscribed to internet service, this will be No)
# 26                                                                                                                                        Indicates the customers current contract type: Month-to-Month, One Year, Two Year
# 27                                                                                                                                                           Indicates if the customer has chosen paperless billing: Yes, No
# 28                                                                                                                                    Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
# 29                                                                                                                             Indicates the customers current total monthly charge for all their services from the company
# 30                                                                                                                              Indicates the customers total charges, calculated to the end of the quarter specified above
# 31                                                                                                                              Indicates the customers total refunds, calculated to the end of the quarter specified above
# 32                                                                            Indicates the customers total charges for extra data downloads above those specified in their plan, by the end of the quarter specified above
# 33                                                                                   Indicates the customers total charges for long distance above those specified in their plan, by the end of the quarter specified above
# 34                  Indicates the company's total revenue from this customer, calculated to the end of the quarter specified above (Total Charges - Total Refurnds + Total Extra Data Charges + Total Lond Distance Charges)
# 35                                                                                                                                Indicates the status of the customer at the end of the quarter: Churned, Stayed, or Joined
# 36                          A high-level category for the customers reason for churning, which is asked when they leave the company: Attitude, Competitor, Dissatisfaction, Other, Price (directly related to Churn Reason)
# 37                                                                                     A customers specific reason for leaving the company, which is asked when they leave the company (directly related to Churn Category)
# 38                                                                                                                                                                          The zip code of the customers primary residence
# 39                                                                                                                                                                A current population estimate for the entire Zip Code area

# %%
print('-'*45)
print('df')
summary(df, False)

print('-'*45)
print('population')
summary(data_population)
# Out:
# ---------------------------------------------
# df
# -----------------
# Data Types:
# object     23
# float64     9
# int64       6
# -----------------
# Num Rows: 7043
# Num Cols: 38
# ---------------------------------------------
# population
# -----------------
# Data Types:
# int64    2
# -----------------
# Num Rows: 1671
# Num Cols: 2
#             Total Null  Num Unique  Dtype
# Zip Code             0        1671  int64
# Population           0        1607  int64

# %% [markdown]
# ## Spliting Data Types

# %%
location = ['City', 'Zip Code', 'Latitude', 'Longitude']
churn = ['Customer Status', 'Churn Category', 'Churn Reason']
drop = location + churn + ['Customer ID']

df_int = df.drop(drop, axis=1).select_dtypes(include='int')
df_float = df.drop(drop, axis=1).select_dtypes(include='float')
df_object = df.drop(drop, axis=1).select_dtypes(include='object')

df_city = df[location]
df_churn = df[churn]

for name, df_type in zip(('integer', 'float', 'object', 'city', 'churn'),
                         (df_int, df_float, df_object, df_city, df_churn)):
    
    print('-'*67)
    print(name)
    summary(df_type)
# Out:
# -------------------------------------------------------------------
# integer
# -----------------
# Data Types:
# int64    5
# -----------------
# Num Rows: 7043
# Num Cols: 5
#                           Total Null  Num Unique  Dtype
# Age                                0          62  int64
# Number of Dependents               0          10  int64
# Number of Referrals                0          12  int64
# Tenure in Months                   0          72  int64
# Total Extra Data Charges           0          16  int64
# -------------------------------------------------------------------
# float
# -----------------
# Data Types:
# float64    7
# -----------------
# Num Rows: 7043
# Num Cols: 7
#                                    Total Null  Num Unique    Dtype
# Avg Monthly Long Distance Charges         682        3583  float64
# Avg Monthly GB Download                  1526          49  float64
# Monthly Charge                              0        1591  float64
# Total Charges                               0        6540  float64
# Total Refunds                               0         500  float64
# Total Long Distance Charges                 0        6068  float64
# Total Revenue                               0        6975  float64
# -------------------------------------------------------------------
# object
# -----------------
# Data Types:
# object    18
# -----------------
# Num Rows: 7043
# Num Cols: 18
#                         Total Null  Num Unique   Dtype
# Gender                           0           2  object
# Married                          0           2  object
# Offer                            0           6  object
# Phone Service                    0           2  object
# Multiple Lines                 682           2  object
# Internet Service                 0           2  object
# Internet Type                 1526           3  object
# Online Security               1526           2  object
# Online Backup                 1526           2  object
# Device Protection Plan        1526           2  object
# Premium Tech Support          1526           2  object
# Streaming TV                  1526           2  object
# Streaming Movies              1526           2  object
# Streaming Music               1526           2  object
# Unlimited Data                1526           2  object
# Contract                         0           3  object
# Paperless Billing                0           2  object
# Payment Method                   0           3  object
# -------------------------------------------------------------------
# city
# -----------------
# Data Types:
# float64    2
# object     1
# int64      1
# -----------------
# Num Rows: 7043
# Num Cols: 4
#            Total Null  Num Unique    Dtype
# City                0        1106   object
# Zip Code            0        1626    int64
# Latitude            0        1626  float64
# Longitude           0        1625  float64
# -------------------------------------------------------------------
# churn
# -----------------
# Data Types:
# object    3
# -----------------
# Num Rows: 7043
# Num Cols: 3
#                  Total Null  Num Unique   Dtype
# Customer Status           0           3  object
# Churn Category         5174           5  object
# Churn Reason           5174          20  object

# %% [markdown]
# ## Investigating Nulls

# %% [markdown]
# ### `df_object`

# %%
df_object['Internet Service'].value_counts()
# Out:
# Yes    5517
# No     1526
# Name: Internet Service, dtype: int64

# %%
df_object[df_object['Internet Service']=='No'].isna().sum()
# Out:
# Gender                       0
# Married                      0
# Offer                        0
# Phone Service                0
# Multiple Lines               0
# Internet Service             0
# Internet Type             1526
# Online Security           1526
# Online Backup             1526
# Device Protection Plan    1526
# Premium Tech Support      1526
# Streaming TV              1526
# Streaming Movies          1526
# Streaming Music           1526
# Unlimited Data            1526
# Contract                     0
# Paperless Billing            0
# Payment Method               0
# dtype: int64

# %%
print(pd.get_dummies(df_object, drop_first=False, prefix_sep=' - ').columns)
print('-'*80)
print(pd.get_dummies(df_object, drop_first=True, prefix_sep=' - ').columns)
# Out:
# Index(['Gender - Female', 'Gender - Male', 'Married - No', 'Married - Yes',
#        'Offer - None', 'Offer - Offer A', 'Offer - Offer B', 'Offer - Offer C',
#        'Offer - Offer D', 'Offer - Offer E', 'Phone Service - No',
#        'Phone Service - Yes', 'Multiple Lines - No', 'Multiple Lines - Yes',
#        'Internet Service - No', 'Internet Service - Yes',
#        'Internet Type - Cable', 'Internet Type - DSL',
#        'Internet Type - Fiber Optic', 'Online Security - No',
#        'Online Security - Yes', 'Online Backup - No', 'Online Backup - Yes',
#        'Device Protection Plan - No', 'Device Protection Plan - Yes',
#        'Premium Tech Support - No', 'Premium Tech Support - Yes',
#        'Streaming TV - No', 'Streaming TV - Yes', 'Streaming Movies - No',
#        'Streaming Movies - Yes', 'Streaming Music - No',
#        'Streaming Music - Yes', 'Unlimited Data - No', 'Unlimited Data - Yes',
#        'Contract - Month-to-Month', 'Contract - One Year',
#        'Contract - Two Year', 'Paperless Billing - No',
#        'Paperless Billing - Yes', 'Payment Method - Bank Withdrawal',
#        'Payment Method - Credit Card', 'Payment Method - Mailed Check'],
#       dtype='object')
# --------------------------------------------------------------------------------
# Index(['Gender - Male', 'Married - Yes', 'Offer - Offer A', 'Offer - Offer B',
#        'Offer - Offer C', 'Offer - Offer D', 'Offer - Offer E',
#        'Phone Service - Yes', 'Multiple Lines - Yes', 'Internet Service - Yes',
#        'Internet Type - DSL', 'Internet Type - Fiber Optic',
#        'Online Security - Yes', 'Online Backup - Yes',
#        'Device Protection Plan - Yes', 'Premium Tech Support - Yes',
#        'Streaming TV - Yes', 'Streaming Movies - Yes', 'Streaming Music - Yes',
#        'Unlimited Data - Yes', 'Contract - One Year', 'Contract - Two Year',
#        'Paperless Billing - Yes', 'Payment Method - Credit Card',
#        'Payment Method - Mailed Check'],
#       dtype='object')

# %% [markdown]
# #### Insights and Solutions
#
# In `df_object` all `NaN` values are related to options included in a service (phone or internet) that the client does not have.
#
# For linear models, they will all kindly disappear after one-hot encoding it with `pd.get_dummies`.

# %% [markdown]
# ### `df_float`

# %%
df_float[df_object['Internet Service']=='No'].isna().sum()
# Out:
# Avg Monthly Long Distance Charges       0
# Avg Monthly GB Download              1526
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Long Distance Charges             0
# Total Revenue                           0
# dtype: int64

# %%
df_float['Avg Monthly GB Download'].describe()
# Out:
# count    5517.000000
# mean       26.189958
# std        19.586585
# min         2.000000
# 25%        13.000000
# 50%        21.000000
# 75%        30.000000
# max        85.000000
# Name: Avg Monthly GB Download, dtype: float64

# %%
df_object['Phone Service'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: Phone Service, dtype: int64

# %%
df_float[df_object['Phone Service']=='No'].isna().sum()
# Out:
# Avg Monthly Long Distance Charges    682
# Avg Monthly GB Download                0
# Monthly Charge                         0
# Total Charges                          0
# Total Refunds                          0
# Total Long Distance Charges            0
# Total Revenue                          0
# dtype: int64

# %%
df_float['Avg Monthly Long Distance Charges'].describe()
# Out:
# count    6361.000000
# mean       25.420517
# std        14.200374
# min         1.010000
# 25%        13.050000
# 50%        25.690000
# 75%        37.680000
# max        49.990000
# Name: Avg Monthly Long Distance Charges, dtype: float64

# %% [markdown]
# #### Insights and Solutions
#
# Similar to `df_object`, the `NaN` values here are also related to not having a service.
#
# For linear models they will be filled with `0`

# %% [markdown]
# ### `df_churn`

# %%
df_churn['Customer Status'].value_counts()
# Out:
# Stayed     4720
# Churned    1869
# Joined      454
# Name: Customer Status, dtype: int64

# %%
df_churn[~df_churn['Churn Category'].isna()]['Customer Status'].value_counts()
# Out:
# Churned    1869
# Name: Customer Status, dtype: int64

# %%
df_churn[~df_churn['Churn Reason'].isna()]['Customer Status'].value_counts()
# Out:
# Churned    1869
# Name: Customer Status, dtype: int64

# %% [markdown]
# #### Insights and Solutions
#
# The `NaN` in `Churn Category` and `Churn Reason` are there when `Customer Status != Churned`
#
# They can be filled accordingly if used as targets.

# %% [markdown]
# ## Class Balance

# %%
plot_countplot(df_churn, fig_cols=3, figsize=(20, 5), rotation=90)

# %%
df_churn['Churn Category'].value_counts()
# Out:
# Competitor         841
# Dissatisfaction    321
# Attitude           314
# Price              211
# Other              182
# Name: Churn Category, dtype: int64

# %%
df_churn.value_counts(dropna=False).sort_index()
# Out:
# Customer Status  Churn Category   Churn Reason
# Churned          Attitude         Attitude of service provider                   94
#                                   Attitude of support person                    220
#                  Competitor       Competitor had better devices                 313
#                                   Competitor made better offer                  311
#                                   Competitor offered higher download speeds     100
#                                   Competitor offered more data                  117
#                  Dissatisfaction  Lack of self-service on Website                29
#                                   Limited range of services                      37
#                                   Network reliability                            72
#                                   Poor expertise of online support               31
#                                   Poor expertise of phone support                12
#                                   Product dissatisfaction                        77
#                                   Service dissatisfaction                        63
#                  Other            Deceased                                        6
#                                   Don't know                                    130
#                                   Moved                                          46
#                  Price            Extra data charges                             39
#                                   Lack of affordable download/upload speed       30
#                                   Long distance charges                          64
#                                   Price too high                                 78
# Joined           NaN              NaN                                           454
# Stayed           NaN              NaN                                          4720
# dtype: int64

# %% [markdown]
# #### Insights and Solutions
#
# LOREM IPSUM

# %% [markdown]
# # Conformal Prediction - Demonstration

# %% [markdown]
# ## LightGBM Classifier

# %% [markdown]
# ### Model

# %%
# Data Split
X = pd.concat([df_int, df_float, df_object.astype('category')], axis=1)
y = df_churn['Customer Status']
y, y_encoder = encoding_labels(y)

X_train, X_calib, X_test, y_train, y_calib, y_test = train_calib_test_split(X, y)

# Model
lgb = LGBMClassifier(n_estimators=1000, random_state=357)
lgb.fit(X_train, y_train,
        eval_set=[(X_calib, y_calib), (X_train, y_train)],
        categorical_feature=list(df_object.columns),
        callbacks=[early_stopping(100), log_evaluation(10)]);

report(X_test, y_test, lgb, y_encoder)
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	training's multi_logloss: 0.368747	valid_0's multi_logloss: 0.433633
# [20]	training's multi_logloss: 0.266013	valid_0's multi_logloss: 0.374273
# [30]	training's multi_logloss: 0.213731	valid_0's multi_logloss: 0.360177
# [40]	training's multi_logloss: 0.17802	valid_0's multi_logloss: 0.360835
# [50]	training's multi_logloss: 0.152957	valid_0's multi_logloss: 0.362604
# [60]	training's multi_logloss: 0.132537	valid_0's multi_logloss: 0.366255
# [70]	training's multi_logloss: 0.114775	valid_0's multi_logloss: 0.375555
# [80]	training's multi_logloss: 0.101207	valid_0's multi_logloss: 0.380957
# [90]	training's multi_logloss: 0.0879493	valid_0's multi_logloss: 0.388388
# [100]	training's multi_logloss: 0.0766544	valid_0's multi_logloss: 0.393577
# [110]	training's multi_logloss: 0.0672924	valid_0's multi_logloss: 0.399898
# [120]	training's multi_logloss: 0.0594208	valid_0's multi_logloss: 0.409243
# [130]	training's multi_logloss: 0.0518684	valid_0's multi_logloss: 0.415653
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.205617	valid_0's multi_logloss: 0.359442
# ----------------------Classification Report----------------------
#               precision    recall  f1-score   support
#
#      Churned       0.72      0.68      0.70       390
#       Joined       0.71      0.71      0.71        90
#       Stayed       0.90      0.91      0.91       929
#
#     accuracy                           0.84      1409
#    macro avg       0.77      0.77      0.77      1409
# weighted avg       0.84      0.84      0.84      1409

# %% [markdown]
# ### Calibration

# %%
from mapie.classification import MapieClassifier

conformal_lgb = MapieClassifier(estimator=lgb, cv="prefit", method="score", random_state=357, verbose=True)
conformal_lgb.fit(X_calib, y_calib)
alphas = [0.2, 0.15, 0.1, 0.05]
y_pred, y_pred_conformal = conformal_lgb.predict(X_test, alpha=alphas)

for k, a in enumerate(alphas):
    count = 0
    for i, j in enumerate(y_test):
        if y_pred_conformal[i, j, k]:
            count += 1
    
    print('-----------------')
    print('alpha:', a)
    print('coverage:', round((count / len(y_test))*100, 2), '%')

calibration_report(X_test, y_test, conformal_lgb, alphas)
# Out:
# -----------------
# alpha: 0.2
# coverage: 80.62 %
# -----------------
# alpha: 0.15
# coverage: 85.24 %
# -----------------
# alpha: 0.1
# coverage: 90.35 %
# -----------------
# alpha: 0.05
# coverage: 95.17 %

# %% [markdown]
# ### Set Intersections

# %%
plot_intersections(y_pred_conformal, y_encoder.inverse_transform(lgb.classes_), alphas)

# %% [markdown]
# ## CatBoost Classifier

# %% [markdown]
# ### Model

# %%
cast = CatBoostClassifier

type(cast)
# Out:
# type

# %%
# Data Split
X = pd.concat([df_int, df_float, df_object.fillna('null').astype('category')], axis=1)
y = df_churn['Customer Status']
y, y_encoder = encoding_labels(y)

X_train, X_calib, X_test, y_train, y_calib, y_test = train_calib_test_split(X, y)

# Model
cat = CatBoostClassifier(random_state=357)
cat.fit(X_train, y_train,
        eval_set=[(X_calib, y_calib)],
        cat_features=list(df_object.columns),
        early_stopping_rounds=100, verbose=25, plot=True);

from sklearn.metrics import classification_report, confusion_matrix

y_pred = cat.predict(X_test)

print('----------------------Classification Report----------------------')
print(classification_report(y_encoder.inverse_transform(y_test), y_encoder.inverse_transform(y_pred)))


labels = y_encoder.inverse_transform(cat.classes_)

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(
    confusion_matrix(y_test, y_pred),
    xticklabels=labels, yticklabels=labels,
    annot=True, cmap='Blues', fmt='g',
);
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Learning rate set to 0.111133
# 0:	learn: 0.9840609	test: 0.9862297	best: 0.9862297 (0)	total: 205ms	remaining: 3m 24s
# 25:	learn: 0.3883800	test: 0.4146493	best: 0.4146493 (25)	total: 1.61s	remaining: 1m
# 50:	learn: 0.3316977	test: 0.3718684	best: 0.3718549 (49)	total: 2.77s	remaining: 51.6s
# 75:	learn: 0.3101552	test: 0.3610687	best: 0.3610687 (75)	total: 3.98s	remaining: 48.4s
# 100:	learn: 0.2936364	test: 0.3543893	best: 0.3543893 (100)	total: 5.24s	remaining: 46.7s
# 125:	learn: 0.2789471	test: 0.3535868	best: 0.3527962 (118)	total: 6.66s	remaining: 46.2s
# 150:	learn: 0.2662959	test: 0.3518070	best: 0.3517506 (149)	total: 7.86s	remaining: 44.2s
# 175:	learn: 0.2574246	test: 0.3503051	best: 0.3499693 (174)	total: 8.98s	remaining: 42.1s
# 200:	learn: 0.2485612	test: 0.3495737	best: 0.3495737 (200)	total: 10s	remaining: 39.9s
# 225:	learn: 0.2399374	test: 0.3493133	best: 0.3491739 (209)	total: 11.2s	remaining: 38.4s
# 250:	learn: 0.2309932	test: 0.3499079	best: 0.3491739 (209)	total: 12.6s	remaining: 37.5s
# 275:	learn: 0.2232332	test: 0.3509877	best: 0.3491739 (209)	total: 13.7s	remaining: 36.1s
# 300:	learn: 0.2150732	test: 0.3507754	best: 0.3491739 (209)	total: 14.8s	remaining: 34.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.3491738539
# bestIteration = 209
#
# Shrink model to first 210 iterations.
# ----------------------Classification Report----------------------
#               precision    recall  f1-score   support
#
#      Churned       0.72      0.71      0.71       390
#       Joined       0.76      0.60      0.67        90
#       Stayed       0.90      0.92      0.91       929
#
#     accuracy                           0.84      1409
#    macro avg       0.79      0.74      0.77      1409
# weighted avg       0.84      0.84      0.84      1409

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = cat.predict(X_test)

print('----------------------Classification Report----------------------')
print(classification_report(y_encoder.inverse_transform(y_test), y_encoder.inverse_transform(y_pred)))


labels = y_encoder.inverse_transform(cat.classes_)

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(
    confusion_matrix(y_test, y_pred),
    xticklabels=labels, yticklabels=labels,
    annot=True, cmap='Blues', fmt='g',
);
# Out:
# ----------------------Classification Report----------------------
#               precision    recall  f1-score   support
#
#      Churned       0.72      0.71      0.71       390
#       Joined       0.76      0.60      0.67        90
#       Stayed       0.90      0.92      0.91       929
#
#     accuracy                           0.84      1409
#    macro avg       0.79      0.74      0.77      1409
# weighted avg       0.84      0.84      0.84      1409

# %% [markdown]
# ### Calibration

# %%
from mapie.classification import MapieClassifier

conformal_cat = MapieClassifier(estimator=cat, cv="prefit", method="score", random_state=357, verbose=True)
conformal_cat.fit(X_calib, y_calib)
alphas = [0.2, 0.15, 0.1, 0.05]
y_pred, y_pred_conformal = conformal_cat.predict(X_test, alpha=alphas)

for k, a in enumerate(alphas):
    count = 0
    for i, j in enumerate(y_test):
        if y_pred_conformal[i, j, k]:
            count += 1
    
    print('-----------------')
    print('alpha:', a)
    print('coverage:', round((count / len(y_test))*100, 2), '%')

calibration_report(X_test, y_test, conformal_cat, alphas)
# Out:
# -----------------
# alpha: 0.2
# coverage: 79.84 %
# -----------------
# alpha: 0.15
# coverage: 85.66 %
# -----------------
# alpha: 0.1
# coverage: 91.27 %
# -----------------
# alpha: 0.05
# coverage: 96.24 %

# %% [markdown]
# ### Set Intersections

# %%
plot_intersections(y_pred_conformal, y_encoder.inverse_transform(cat.classes_), alphas)
